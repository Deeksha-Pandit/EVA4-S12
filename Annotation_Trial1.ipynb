# %% [markdown]
# <a href="https://colab.research.google.com/github/Deeksha-Pandit/EVA4-S12/blob/master/Annotation_Trial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd 
file = open('via_export_coco.json')
data = json.load(file)
print(data.keys())
# Out:
# dict_keys(['info', 'images', 'annotations', 'licenses', 'categories'])

# %%
images = pd.DataFrame(data['images'], columns = data['images'][0].keys())
annotations = pd.DataFrame(data['annotations'], columns = data['annotations'][0].keys())
print(images,'\n')
print('################################################################')
print(annotations)
# Out:
#     id  width  height file_name  license date_captured
# 0    0    900     600     1.jpg        1
# 1    1   1200     600     2.jpg        1
# 2    2   1254     836     3.jpg        1
# 3    3    540     405     4.jpg        1
# 4    4   1024    1024     5.jpg        1
# 5    5   1000     666     6.jpg        1
# 6    6    768     520     7.jpg        1
# 7    7    900     597     8.png        1
# 8    8    500     333     9.jpg        1
# 9    9    460     623    10.jpg        1
# 10  10   1200     880    11.jpg        1
# 11  11    750     422    12.jpg        1
# 12  12    444     330    13.png        1
# 13  13    650     433    14.jpg        1
# 14  14    390     400    15.png        1
# 15  15    600     900    16.jpg        1
# 16  16    864     500    17.jpg        1
# 17  17    300     300    18.jpg        1
# 18  18    432     300    19.jpg        1
# 19  19   1024     683    20.jpg        1
# 20  20    660     471    21.jpg        1
# ...

# %%
file.close()

# %%
b_width = []
b_height = []
files_concat = pd.concat([images,annotations],axis=1)
files_split = files_concat.drop(["id","image_id","license","iscrowd","area","segmentation","date_captured"],axis=1)
#new = files_split["bbox"].str.split([1:3])'
#new=files_split["bbox"][:2]
#print(new)
#df=pd.DataFrame(files_split["bbox"])
for i in range(50):
  print(files_split["bbox"][1].type())
  #b_width.append(a)
  #b_height = files_split["bbox"][i][3]
#print(b_width)#," ",b_height)
#files_split1 = files_split.bbox.str.split()
#print(files_split)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-113476c03267> in <module>()
#       8 #df=pd.DataFrame(files_split["bbox"])
#       9 for i in range(50):
# ---> 10   print(files_split["bbox"][1].type())
#      11   #b_width.append(a)
#      12   #b_height = files_split["bbox"][i][3]
#
# AttributeError: 'list' object has no attribute 'type'
